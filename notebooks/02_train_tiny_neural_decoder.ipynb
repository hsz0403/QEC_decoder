# %% [markdown]
# # Train a tiny neural decoder
#
# Use `scripts/train.py --config configs/train_mlp_d3_smoke.yaml` for the flat MLP or `configs/train_mini_aq_d3_smoke.yaml` for the mini AlphaQubit-style model.
